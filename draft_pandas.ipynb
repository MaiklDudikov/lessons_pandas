# %%
import pandas as pd

# %%
a = [54, 6, 7, 43, 43]

# %%
num = pd.Series(a)
num

# %%
names = ['John', 'Jane', 'Alice']
ages = [25, 30, 27]
with_name = pd.Series(ages, index=names, name='Products')
with_name
# with_name.name
# print(f'Age by Name: {with_name["Jane"]}')

# %% [markdown]
# открыть файл для чтения

# %%
sample = pd.read_csv('sample_data.csv')

# %% [markdown]
# вывести первые 10 строк

# %%
sample.head(10)

# %%
top_10 = sample.head(10)
top_10
#print(top_10)
#top_10.loc[:5, ['first_name', 'last_name']]

# %% [markdown]
# создание pandas DataFrame (таблицы) из файла sample_data.csv

# %%
table = pd.DataFrame(sample)

# %%
table
# Out:
#        id first_name  last_name                            email  gender  \
# 0       1   Torrence      Beaby                tbeaby0@imgur.com    Male
# 1       2      Carey     Ortner  cortner1@scientificamerican.com    Male
# 2       3      Misty     Piller             mpiller2@example.com  Female
# 3       4   Violante  Lancaster           vlancaster3@paypal.com  Female
# 4       5       Birk     Faiers              bfaiers4@zimbio.com    Male
# ..    ...        ...        ...                              ...     ...
# 995   996      Micky     Sheals              mshealsrn@upenn.edu    Male
# 996   997  Heindrick     Wakely             hwakelyro@discuz.net    Male
# 997   998        Ody      Gurys              ogurysrp@seesaa.net    Male
# 998   999    Skipper    McAmish               smcamishrq@npr.org    Male
# 999  1000     Romona      Doull         rdoullrr@accuweather.com  Female
#
#           ip_address
# 0      77.121.12.215
# 1     204.214.150.22
# 2     186.32.212.108
# ...

# %% [markdown]
# iloc выбирает строки и столбцы в определенных целочисленных позициях

# %%
table.iloc[0]
# Out:
# id                            1
# first_name             Torrence
# last_name                 Beaby
# email         tbeaby0@imgur.com
# gender                     Male
# ip_address        77.121.12.215
# Name: 0, dtype: object

# %% [markdown]
# loc выбирает строки и столбцы с определенными метками

# %%
table.loc[:, 'email']
# Out:
# 0                    tbeaby0@imgur.com
# 1      cortner1@scientificamerican.com
# 2                 mpiller2@example.com
# 3               vlancaster3@paypal.com
# 4                  bfaiers4@zimbio.com
#                     ...
# 995                mshealsrn@upenn.edu
# 996               hwakelyro@discuz.net
# 997                ogurysrp@seesaa.net
# 998                 smcamishrq@npr.org
# 999           rdoullrr@accuweather.com
# Name: email, Length: 1000, dtype: object

# %%
data = {
    'Bob': ['I liked That', 'That was awful'],
    'Sue': ['Pretty Good', 'Tasty']
}

pd.DataFrame(
    data,
    index=['Product A', 'Product B'],
)
# Out:
#                       Bob          Sue
# Product A    I liked That  Pretty Good
# Product B  That was awful        Tasty

# %%
df = pd.DataFrame({
    'team': ['A', 'A', 'A', 'A', 'B', 'B', 'B', 'B'],
    'points': [5, 7, 7, 9, 12, 9, 9, 4],
    'assists': [11, 8, 10, 6, 6, 5, 9, 12]},
    index=['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H'])
df
